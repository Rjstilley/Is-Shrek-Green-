# %%
import pandas as pd

# %%
url = "https://www.nei.nih.gov/learn-about-eye-health/resources-for-health-educators/eye-health-data-and-statistics/blindness-data-and-statistics/blindness-tables"

# %%
read = pd.read_html(url)

# %%
read[0]
# Out:
#      Age  White  Black  Hispanic  Other   All
# 0  40-49     34     10         4      4    52
# 1  50-54     16      9         2      3    30
# 2  55-59     16     11         3      4    34
# 3  60-64     18     13         4      4    39
# 4  65-69     23     14         4      5    46
# 5  70-74     32     16         5      5    58
# 6  75-79     59     18         5      5    87
# 7    80+    867     50        14     14   945
# 8  TOTAL   1065    141        41     44  1291

# %%
read[1]
# Out:
#          Unnamed: 0        All      White     Black  Hispanic    Other
# 0  Total Population  142648393  103846437  15190777  14901369  8709810

# %%
read[2]
# Out:
#      Age  White  Black  Hispanic  Other   All
# 0  40-49     34     10         4      4    52
# 1  50-54     16      9         2      3    30
# 2  55-59     16     11         3      4    34
# 3  60-64     18     13         4      4    39
# 4  65-69     23     14         4      5    46
# 5  70-74     32     16         5      5    58
# 6  75-79     59     18         5      5    87
# 7    80+    867     50        14     14   945
# 8  TOTAL   1065    141        41     44  1291

# %%
read[3]
# Out:
#   Female/Age  White  Black  Hispanic  Other  All
# 0      40-49     17      5         2      2   26
# 1      50-54      8      5         1      2   16
# 2      55-59      8      6         2      2   18
# 3      60-64      9      7         2      2   20
# 4      65-69     12      8         2      3   25
# 5      70-74     17      9         3      3   32
# 6      75-79     33     11         3      3   50
# 7        80+    606     35         9      9  659
# 8      TOTAL    710     86        24     26  846

# %%
read[4]
# Out:
#   Male/Age  White  Black  Hispanic  Other  All
# 0    40-49     17      5         2      2   26
# 1    50-54      8      4         1      1   14
# 2    55-59      8      5         1      2   16
# 3    60-64      9      6         2      2   19
# 4    65-69     11      6         2      2   21
# 5    70-74     15      7         2      2   26
# 6    75-79     26      7         2      2   37
# 7      80+    261     15         5      5  286
# 8    TOTAL    355     55        17     18  445

# %%
for i
# Out:
# [     Age  White  Black Hispanic  Other    All
#  0  40-49  0.12%  0.18%    0.05%  0.11%  0.12%
#  1  50-54  0.10%  0.34%    0.11%  0.20%  0.13%
#  2  55-59  0.11%  0.52%    0.16%  0.31%  0.17%
#  3  60-64  0.14%  0.80%    0.26%  0.47%  0.24%
#  4  65-69  0.23%  1.24%    0.40%  0.72%  0.36%
#  5  70-74  0.43%  1.91%    0.64%  1.10%  0.62%
#  6  75-79  0.99%  2.93%    1.00%  1.67%  1.18%
#  7    80+  9.21%  6.32%    2.15%  3.46%  8.41%
#  8  TOTAL  1.02%  0.93%    0.26%  0.51%  0.90%,
#           Unnamed: 0        All      White     Black  Hispanic    Other
#  0  Total Population  142648393  103846437  15190777  14901369  8709810,
#       Age  White  Black  Hispanic  Other   All
#  0  40-49     34     10         4      4    52
#  1  50-54     16      9         2      3    30
#  2  55-59     16     11         3      4    34
#  3  60-64     18     13         4      4    39
#  4  65-69     23     14         4      5    46
#  5  70-74     32     16         5      5    58
# ...
